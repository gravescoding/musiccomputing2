# %% [markdown]
# <a href="https://colab.research.google.com/github/gravescoding/musiccomputing2/blob/main/assignments/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2025.git
# Out:
# Cloning into 'musicComputing2025'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 125 (delta 56), reused 18 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 17.83 MiB | 5.53 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
def plotAudio2(sig,sampleRate,title):

    # add in the code from Assignment 2

   time=np.arange(0,sig.shape[0])/sr


   # Scale the y-axis to represent amplitude from -1 to 1
   excursion=max(abs(sig))
   sigNew = sig / excursion


   # Label the x and y axes with variables
   xlabel = 'Time (seconds)'
   ylabel = 'Amplitude'


   #plot the signal using the x and y axis variables
   plt.plot(time,sigNew)
   plt.xlabel(xlabel)
   plt.ylabel(ylabel)
   plt.title(title)
   plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):


    # create a normalized spectrogram
    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    librosa.stft(sig,n_fft=winSize)
    # then make all of values in the spectrogram positive with np.abs()
    np.abs(librosa.stft(sig,n_fft=winSize))
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()
    librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)))
    # then plot the spectrogram with librosa.display.specshow()
    librosa.display.specshow(librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)),ref=np.max),y_axis=specType,x_axis='time')

    # display the normalized spectrogram with a log frequency scale
    plt.title(title)
    plt.show()

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):

    #call plotAudio2
    plotAudio2(sig,sr,title)

    #call plotAudioFreqDomain
    plotAudioFreqDomain(sig,sr,title,winSize,specType)

# %%
sig , sr = librosa.load('musicComputing2025/audioFiles/avm.wav')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'

#call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)
# Out:
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# <ipython-input-39-b2606e1970aa> in <cell line: 0>()
#       4
#       5 #call plotAudioFunc
# ----> 6 plotAudioFunc(sig,sr,title,winSize,specType)
#       7
#
# <ipython-input-37-be0cbd37c370> in plotAudioFunc(sig, sr, title, winSize, specType)
#       5
#       6     #call plotAudioFreqDomain
# ----> 7     plotAudioFreqDomain(sig,sr,title,winSize,specType)
#       8
#
# <ipython-input-36-b4e956e39fd2> in plotAudioFreqDomain(sig, sr, title, winSize, specType)
#      11     librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)))
#      12     # then plot the spectrogram with librosa.display.specshow()
# ---> 13     librosa.display.specshow(librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)),ref=np.max),y_axis=specType,x_axis=12)
#      14
#      15     # display the normalized spectrogram with a log frequency scale
#
# /usr/local/lib/python3.11/dist-packages/librosa/display.py in specshow(data, x_coords, y_coords, x_axis, y_axis, sr, hop_length, n_fft, win_length, fmin, fmax, tempo_min, tempo_max, tuning, bins_per_octave, key, Sa, mela, thaat, auto_aspect, htk, unicode, intervals, unison, ax, **kwargs)
#    1210     # Get the x and y coordinates
#    1211     y_coords = __mesh_coords(y_axis, y_coords, data.shape[0], **all_params)
# -> 1212     x_coords = __mesh_coords(x_axis, x_coords, data.shape[1], **all_params)
#    1213
#    1214     axes = __check_axes(ax)
#
# /usr/local/lib/python3.11/dist-packages/librosa/display.py in __mesh_coords(ax_type, coords, n, **kwargs)
#    1317
#    1318     if ax_type not in coord_map:
# -> 1319         raise ParameterError(f"Unknown axis type: {ax_type}")
#    1320     return coord_map[ax_type](n, **kwargs)
#    1321
#
# ParameterError: Unknown axis type: 12

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'

#call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'


# call plotAudioFunc
plotAudioFunc(sig,sr,title,winSize,specType)

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'

plotAudioFunc(sig,sr,title,winSize,specType)
